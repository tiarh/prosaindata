# %% [markdown]
# # Crawling PTA

# %%
import requests as requ
from bs4 import BeautifulSoup as bso
from datetime import datetime
import csv
import pandas as pd

hades = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}

# %%
url = 'https://pta.trunojoyo.ac.id/welcome/index/'

headers = {
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Mobile Safari/537.36'
}

temp = []
for page in range(1, 50):
  req = requ.get(url+str(page), headers=headers)
  bs = bso(req.text, 'html.parser')
  items = bs.findAll('li', {'data-id':'id-1'})
  for item in items:
    # temp = []
    title = item.find('a', 'title').text
    writer = item.find('span', '').text.replace('Penulis :', '')
    abstrac = item.find('p', {'align': 'justify'}).text
    temp.append([title, writer, abstrac])
print(temp)
# Out:
# [['STRATEGI PENGEMBANGAN MAKANAN DAN MINUMAN KHAS PULAU GILIGENTING GUNA MENDUKUNG PARIWISATA BERKELANJUTAN', ' Mohammad Maskur', 'Makanan dan minuman khas merupakan ciri dari kekayaan sumberdaya alam dari suatu daerah, pentingnya memaksimalkan pariwisata Pulau Giligenting ditunjang dengan…'], ['PERUMUSAN SANKSI PIDANA BAGI MASYARAKAT SEKITAR HUTAN YANG MELAKUKAN PENCURIAN KAYU MILIK NEGARA DALAM UNDANG-UNDANG NOMOR 18 TAHUN 2013', ' Moch. Steven', 'ABSTRAK\nAkhir-akhir ini semakin maraknya pencurian kayu milik negara di sekitar hutan oleh masyarakat. akan tetapi perumusan sanksi pidana dalam…'], ['Peran Teor Motivasi Herzberg Sebagai Mediator Self Efficacy, Lingkungan Kerja Dalam Meningkatkan Prestasi Kerja Pegawai ( Kantor Jasa Penilai Publik Guntur Eki Andri dan Rekan Kota Surabaya )', ' Widha Deby Andrea', 'Penelitian ini bertujuan untuk dapat mengetahui tentang pengaruh motivasi kerja sebagai mediator self efficacy dan lingkungan kerja terhadap prestasi kerja…'], ['ANALISIS KAND
# ...

# %%
df = pd.DataFrame(temp, columns=['Judul', 'Penulis', 'Abstrak'])
df
# Out:
#                                                  Judul  \
# 0    STRATEGI PENGEMBANGAN MAKANAN DAN MINUMAN KHAS...
# 1    PERUMUSAN SANKSI PIDANA BAGI MASYARAKAT SEKITA...
# 2    Peran Teor Motivasi Herzberg Sebagai Mediator ...
# 3    ANALISIS KANDUNGAN TIMBAL (Pb) UDANG REBON (Ac...
# 4    Analisis Wacana Media Online Detik.com dalam M...
# ..                                                 ...
# 142  An Analysis of Figurative Language in Selected...
# 143  HAMBATAN KOMUNIKASI MAHASISWA PAPUA (Studi Des...
# 144  PENGARUH MEDIA VIRTUAL REALITY BERBANTUAN GOOG...
# 145  ANALISIS PENGGUNAAN KALIMAT ANALITIS,KONTRADIK...
# 146  PENGARUH PENAMBAHAN NaOH TERHADAP PENINGKATAN ...
#
#                                 Penulis  \
# 0                       Mohammad Maskur
# 1                          Moch. Steven
# 2                     Widha Deby Andrea
# 3     Roihatul Jannah dan Haryo Triajie
# 4                    RIAN PANDI PRANATA
# ..                                  ...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/prosaindata/pta.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df.to_csv(f)
# Out:
# Mounted at /content/drive
